# %% [markdown]
# <a href="https://colab.research.google.com/github/wenxuan0923/My-notes/blob/master/style_pandas_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Dataframe Styling
#
# In this note I will apply **conditional formatting**, the visual styling of a DataFrame depending on the data within, by using the `DataFrame.style property`. The following techniques will be covered here:
#
# - `Styler.applymap(func)`, which operates on DataFrames elementwise
#
# - `Styler.apply(func, axis)`, which operates on DataFrames' column/rows
# > Styler.apply(func, axis=0) for columnwise styles
# >
# > Styler.apply(func, axis=1) for rowwise styles
# >
# > Styler.apply(func, axis=None) for tablewise styles
#
# - `Styler.background_gradient` create heatmap with dataframe data
#
# - `Styler.bar`, include barchart in the dataframe
#
# - `Styler.set_properties` apply styles doesn’t depend on values
#
# - `Styler.set_table_styles` apply styles to the table as a whole
#
# Reference: https://pandas.pydata.org/pandas-docs/version/0.18/style.html

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset used in this note can be downloaded here: <a target='_blank' href='https://www.kaggle.com/kaggle/sf-salaries'>SF Salaries</a>.

# %%
df = pd.read_csv('SF_Salaries.csv')
# randomly pick 20 samples for simplicity
df = df.sample(20)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Id             EmployeeName  ...         Agency Status
# 47607    47608          Brenda Mitchell  ...  San Francisco    NaN
# 70468    70469             Rickey White  ...  San Francisco    NaN
# 53970    53971        Magdalena Zaldana  ...  San Francisco    NaN
# 45623    45624            Zoila Lechuga  ...  San Francisco    NaN
# 12824    12825         NORA ZAPATA-KREY  ...  San Francisco    NaN
# 121421  121422          Vernon C Abrams  ...  San Francisco     FT
# 112759  112760      Tisileli T Lupeheke  ...  San Francisco     FT
# 88223    88224        Christine  Gerber  ...  San Francisco    NaN
# 67955    67956           Marvin Cullado  ...  San Francisco    NaN
# 140910  140911        Pastora A Ancheta  ...  San Francisco     PT
# 140778  140779                Hui M Mai  ...  San Francisco     PT
# 72644    72645            Marian Fields  ...  San Francisco    NaN
# 38047    38048       Jane Newhard-Parks  ...  San Francisco    NaN
# 191        192               GRAD GREEN  ...  San Francisco    NaN
# 115917  115918              Alice L Yan  ...  San Francisco     FT
# 138895  138896           Natasha Michel  ...  San Francisco     PT
# 142465  142466  Warren Andrei M Mallari  ...  San Francisco     PT
# 107986  107987          Charles L Cecil  ...  San Francisco    NaN
# 60514    60515             Norma Castro  ...  San Francisco    NaN
# 120532  120533            Lillian Louie  ...  San Francisco     FT
#
# [20 rows x 13 columns]

# %%
# Convert the monetary fields to numerical value
monetary_fields = ['BasePay', 'OvertimePay', 'OtherPay', 
                   'Benefits', 'TotalPay', 'TotalPayBenefits']
df[monetary_fields] = df[monetary_fields].apply(pd.to_numeric)

# %% [markdown]
# There are two types of methods when applying style to the dataframe:
#
# - `Styler.applymap`: elementwise style
#
# - `Styler.apply`: column-/row-/table-wise style
#
# ### Apply different colors base on a threshold with `Styler.applymap`
# Make the text green for the cells whose `TotalPay` higher than average and red for value lower than average salary.

# %%
def color_lower_red(val):
    """
    'green' when TotalPay higher than average
    'red' when TotalPay lower than average
    """
    average_salary = 56516
    color = 'red' if val < average_salary else 'green'
    return 'color: %s' % color

df.style\
  .applymap(color_lower_red, subset=['TotalPay'])\
  .format({field:"${:20,.0f}" for field in monetary_fields}, na_rep="-")
# Out:
# <style  type="text/css" >
#     #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row3_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row4_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row5_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row6_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row7_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row8_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row9_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row10_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row11_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row12_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row13_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row14_col7 {
#             color:  green;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row15_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row16_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row17_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row18_col7 {
#             color:  red;
#         }    #T_34ad52be_b02a_11ea_bc91_0242ac1c0002row19_col7 {
#             color:  green;
#         }</style><table id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Id</th>        <th class="col_heading level0 col1" >EmployeeName</th>        <th class="col_heading level0 col2" >JobTitle</th>        <th class="col_heading level0 col3" >BasePay</th>        <th class="col_heading level0 col4" >OvertimePay</th>        <th class="col_heading level0 col5" >OtherPay</th>        <th class="col_heading level0 col6" >Benefits</th>        <th class="col_heading level0 col7" >TotalPay</th>        <th class="col_heading level0 col8" >TotalPayBenefits</th>        <th class="col_heading level0 col9" >Year</th>        <th class="col_heading level0 col10" >Notes</th>        <th class="col_heading level0 col11" >Agency</th>        <th class="col_heading level0 col12" >Status</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002level0_row0" class="row_heading level0 row0" >47607</th>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col0" class="data row0 col0" >47608</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col1" class="data row0 col1" >Brenda Mitchell</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col2" class="data row0 col2" >Supervising Parts Storekeeper</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col3" class="data row0 col3" >$              72,878</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col4" class="data row0 col4" >$              22,347</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col5" class="data row0 col5" >$                 221</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col6" class="data row0 col6" >$              34,278</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col7" class="data row0 col7" >$              95,446</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col8" class="data row0 col8" >$             129,724</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col9" class="data row0 col9" >2012</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col10" class="data row0 col10" >nan</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col11" class="data row0 col11" >San Francisco</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row0_col12" class="data row0 col12" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002level0_row1" class="row_heading level0 row1" >70468</th>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col0" class="data row1 col0" >70469</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col1" class="data row1 col1" >Rickey White</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col2" class="data row1 col2" >IS Programmer Analyst</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col3" class="data row1 col3" >$               3,730</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col4" class="data row1 col4" >$                   0</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col5" class="data row1 col5" >$                   0</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col6" class="data row1 col6" >$               1,107</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col7" class="data row1 col7" >$               3,730</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col8" class="data row1 col8" >$               4,837</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col9" class="data row1 col9" >2012</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col10" class="data row1 col10" >nan</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col11" class="data row1 col11" >San Francisco</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row1_col12" class="data row1 col12" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002level0_row2" class="row_heading level0 row2" >53970</th>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col0" class="data row2 col0" >53971</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col1" class="data row2 col1" >Magdalena Zaldana</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col2" class="data row2 col2" >Patient Care Assistant</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col3" class="data row2 col3" >$              63,035</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col4" class="data row2 col4" >$               4,687</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col5" class="data row2 col5" >$               5,091</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col6" class="data row2 col6" >$              30,875</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col7" class="data row2 col7" >$              72,813</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col8" class="data row2 col8" >$             103,688</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col9" class="data row2 col9" >2012</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_34ad52be_b02a_11ea_bc91_0242ac1c0002row2_col11" class="data row2 col11" >San Fra

# %% [markdown]
# ### Highlight the maximum value in the specified column with `Styler.apply`

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: rgba(237, 52, 52, 0.5)' if v else '' for v in is_max]

df.style\
  .apply(highlight_max, subset=monetary_fields)\
  .format({field:"${:20,.0f}" for field in monetary_fields}, na_rep="-")
# Out:
# <style  type="text/css" >
#     #T_505a55ce_b02b_11ea_bc91_0242ac1c0002row6_col4 {
#             background-color:  rgba(237, 52, 52, 0.5);
#         }    #T_505a55ce_b02b_11ea_bc91_0242ac1c0002row6_col8 {
#             background-color:  rgba(237, 52, 52, 0.5);
#         }    #T_505a55ce_b02b_11ea_bc91_0242ac1c0002row12_col6 {
#             background-color:  rgba(237, 52, 52, 0.5);
#         }    #T_505a55ce_b02b_11ea_bc91_0242ac1c0002row13_col3 {
#             background-color:  rgba(237, 52, 52, 0.5);
#         }    #T_505a55ce_b02b_11ea_bc91_0242ac1c0002row13_col5 {
#             background-color:  rgba(237, 52, 52, 0.5);
#         }    #T_505a55ce_b02b_11ea_bc91_0242ac1c0002row13_col7 {
#             background-color:  rgba(237, 52, 52, 0.5);
#         }</style><table id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Id</th>        <th class="col_heading level0 col1" >EmployeeName</th>        <th class="col_heading level0 col2" >JobTitle</th>        <th class="col_heading level0 col3" >BasePay</th>        <th class="col_heading level0 col4" >OvertimePay</th>        <th class="col_heading level0 col5" >OtherPay</th>        <th class="col_heading level0 col6" >Benefits</th>        <th class="col_heading level0 col7" >TotalPay</th>        <th class="col_heading level0 col8" >TotalPayBenefits</th>        <th class="col_heading level0 col9" >Year</th>        <th class="col_heading level0 col10" >Notes</th>        <th class="col_heading level0 col11" >Agency</th>        <th class="col_heading level0 col12" >Status</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002level0_row0" class="row_heading level0 row0" >47607</th>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col0" class="data row0 col0" >47608</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col1" class="data row0 col1" >Brenda Mitchell</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col2" class="data row0 col2" >Supervising Parts Storekeeper</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col3" class="data row0 col3" >$              72,878</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col4" class="data row0 col4" >$              22,347</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col5" class="data row0 col5" >$                 221</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col6" class="data row0 col6" >$              34,278</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col7" class="data row0 col7" >$              95,446</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col8" class="data row0 col8" >$             129,724</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col9" class="data row0 col9" >2012</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col10" class="data row0 col10" >nan</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col11" class="data row0 col11" >San Francisco</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row0_col12" class="data row0 col12" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002level0_row1" class="row_heading level0 row1" >70468</th>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col0" class="data row1 col0" >70469</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col1" class="data row1 col1" >Rickey White</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col2" class="data row1 col2" >IS Programmer Analyst</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col3" class="data row1 col3" >$               3,730</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col4" class="data row1 col4" >$                   0</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col5" class="data row1 col5" >$                   0</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col6" class="data row1 col6" >$               1,107</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col7" class="data row1 col7" >$               3,730</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col8" class="data row1 col8" >$               4,837</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col9" class="data row1 col9" >2012</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col10" class="data row1 col10" >nan</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col11" class="data row1 col11" >San Francisco</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row1_col12" class="data row1 col12" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002level0_row2" class="row_heading level0 row2" >53970</th>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col0" class="data row2 col0" >53971</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col1" class="data row2 col1" >Magdalena Zaldana</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col2" class="data row2 col2" >Patient Care Assistant</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col3" class="data row2 col3" >$              63,035</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col4" class="data row2 col4" >$               4,687</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col5" class="data row2 col5" >$               5,091</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col6" class="data row2 col6" >$              30,875</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col7" class="data row2 col7" >$              72,813</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col8" class="data row2 col8" >$             103,688</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col9" class="data row2 col9" >2012</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col11" class="data row2 col11" >San Francisco</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row2_col12" class="data row2 col12" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002level0_row3" class="row_heading level0 row3" >45623</th>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row3_col0" class="data row3 col0" >45624</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row3_col1" class="data row3 col1" >Zoila Lechuga</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row3_col2" class="data row3 col2" >Public SafetyComm Disp</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row3_col3" class="data row3 col3" >$              79,040</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row3_col4" class="data row3 col4" >$              19,331</td>
#                         <td id="T_505a55ce_b02b_11ea_bc91_0242ac1c0002row3_col5" class="data row3 col5" >$               5,553</td>
#                         <td id="T_5

# %% [markdown]
# ### Create "heatmaps" with the `background_gradient`
#
# `Styler.background_gradient` takes the keyword arguments `low` and `high`. Roughly speaking these extend the range of your data by low and high percent so that when we convert the colors, the colormap's entire range isn't used, such that the color won't be too dark/light, we can still read the text.

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)

df.style\
  .background_gradient(cmap=cmap, low=.2, high=0.8,
                       subset=monetary_fields)\
  .format("${:20,.0f}", na_rep="-",
          subset=monetary_fields)
# Out:
# <style  type="text/css" >
#     #T_91b9c358_b029_11ea_bc91_0242ac1c0002row0_col3 {
#             background-color:  #e0afb3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row0_col4 {
#             background-color:  #e8c2bf;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row0_col5 {
#             background-color:  #f5e5de;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row0_col6 {
#             background-color:  #cf91a3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row0_col7 {
#             background-color:  #dca7ae;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row0_col8 {
#             background-color:  #cf91a3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row1_col3 {
#             background-color:  #f4e4dd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row1_col4 {
#             background-color:  #f5e6e0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row1_col5 {
#             background-color:  #f5e6e0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row1_col6 {
#             background-color:  #f4e4dd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row1_col7 {
#             background-color:  #f4e4dd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row1_col8 {
#             background-color:  #f4e4dd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row2_col3 {
#             background-color:  #e3b6b7;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row2_col4 {
#             background-color:  #f2dfd8;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row2_col5 {
#             background-color:  #edcfc9;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row2_col6 {
#             background-color:  #d59aa7;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row2_col7 {
#             background-color:  #e3b6b7;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row2_col8 {
#             background-color:  #daa2ac;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row3_col3 {
#             background-color:  #ddaab0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row3_col4 {
#             background-color:  #eac7c3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row3_col5 {
#             background-color:  #ecccc7;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row3_col6 {
#             background-color:  #cb8ca0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row3_col7 {
#             background-color:  #daa2ac;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row3_col8 {
#             background-color:  #cb8ca0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row4_col3 {
#             background-color:  #dca6ae;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row4_col4 {
#             background-color:  #f5e6e0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row4_col5 {
#             background-color:  #f1dcd6;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row4_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row4_col7 {
#             background-color:  #dfaeb2;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row4_col8 {
#             background-color:  #e0afb3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row5_col3 {
#             background-color:  #e2b3b5;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row5_col4 {
#             background-color:  #e7bfbd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row5_col5 {
#             background-color:  #eac7c3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row5_col6 {
#             background-color:  #cc8da1;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row5_col7 {
#             background-color:  #dba5ad;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row5_col8 {
#             background-color:  #cd8ea1;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row6_col3 {
#             background-color:  #dca7ae;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row6_col4 {
#             background-color:  #a7658e;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row6_col5 {
#             background-color:  #e7bfbd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row6_col6 {
#             background-color:  #ce8fa2;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row6_col7 {
#             background-color:  #bb7797;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row6_col8 {
#             background-color:  #a7658e;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row7_col3 {
#             background-color:  #dca7ae;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row7_col4 {
#             background-color:  #f5e6e0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row7_col5 {
#             background-color:  #f2ded7;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row7_col6 {
#             background-color:  #d59ba8;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row7_col7 {
#             background-color:  #e0afb3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row7_col8 {
#             background-color:  #d59ba8;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row8_col3 {
#             background-color:  #f3e0d9;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row8_col4 {
#             background-color:  #f5e6e0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row8_col5 {
#             background-color:  #f4e4dd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row8_col6 {
#             background-color:  #f1dad3;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row8_col7 {
#             background-color:  #f3e0d9;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row8_col8 {
#             background-color:  #f1dcd6;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row9_col3 {
#             background-color:  #eed4cd;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row9_col4 {
#             background-color:  #f5e6e0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row9_col5 {
#             background-color:  #f5e5de;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row9_col6 {
#             background-color:  #f5e5de;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row9_col7 {
#             background-color:  #efd6d0;
#             color:  #000000;
#         }    #T_91b9c358_b029_11ea_bc91_0242ac1c0002row9_col8 {
#             background-color:  #efd6d0;
#             color:  #000000;

# %% [markdown]
# ### Include Bar Charts in the dataframe

# %%
df[monetary_fields].style\
                   .set_caption('Include Bar charts in dataframe')\
                   .bar(subset=monetary_fields, 
                        align='mid', color='lightsteelblue') \
                   .highlight_null(null_color='seashell') \
                   .format("${:20,.0f}", na_rep="-")
# Out:
# <style  type="text/css" >
#     #T_393b4414_b028_11ea_bc91_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 40.8%, transparent 40.8%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 26.6%, transparent 26.6%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 0.8%, transparent 0.8%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 62.3%, transparent 62.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row0_col4 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 46.1%, transparent 46.1%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 62.1%, transparent 62.1%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 2.1%, transparent 2.1%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row1_col2 {
#             width:  10em;
#              height:  80%;
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 2.0%, transparent 2.0%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row1_col4 {
#             color:  red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 1.8%, transparent 1.8%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 2.3%, transparent 2.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 35.3%, transparent 35.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 5.6%, transparent 5.6%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 17.7%, transparent 17.7%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 56.1%, transparent 56.1%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row2_col4 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 35.1%, transparent 35.1%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 49.6%, transparent 49.6%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 44.3%, transparent 44.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 23.0%, transparent 23.0%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 19.4%, transparent 19.4%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 66.8%, transparent 66.8%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row3_col4 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 50.2%, transparent 50.2%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 67.3%, transparent 67.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 46.8%, transparent 46.8%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 7.3%, transparent 7.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row4_col3 {
#             : ;
#             background-color:  seashell;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row4_col4 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 41.3%, transparent 41.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 41.0%, transparent 41.0%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 37.6%, transparent 37.6%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 29.0%, transparent 29.0%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 23.3%, transparent 23.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 66.7%, transparent 66.7%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row5_col4 {
#             color:  green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 47.3%, transparent 47.3%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 64.5%, transparent 64.5%);
#             : ;
#         }    #T_393b4414_b028_11ea_bc91_0242ac1c0002row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 45.7%, transparent 45.7%);

# %% [markdown]
# ### Apply style doesn’t actually depend on values with `Styler.set_properties`

# %%
df.style.set_properties(**{'background-color': 'steelblue',
                           'color': 'white',
                           'text-align': 'center',
                           'padding': '0.5rem',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col0 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col1 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col2 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col3 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col4 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col5 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col6 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col7 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col8 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col9 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col10 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col11 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row0_col12 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col0 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col1 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col2 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col3 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col4 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col5 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col6 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col7 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col8 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col9 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col10 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col11 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row1_col12 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col0 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col1 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col2 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col3 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col4 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col5 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col6 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col7 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:  center;
#             padding:  0.5rem;
#             border-color:  white;
#         }    #T_132c9ef4_b02c_11ea_bc91_0242ac1c0002row2_col8 {
#             background-color:  steelblue;
#             color:  white;
#             text-align:

# %% [markdown]
# ### Table Styles with `Styler.set_table_styles`
#
# You need have some basic knowledge about css styling to apply table styles. The css style is passed in to the `props` argument with format `('style_name', 'value')`.

# %%
from IPython.display import HTML

def hover(hover_color="rgba(177, 201, 227, 0.4)"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])
    
styles = [
    hover(),
    dict(selector=".col_heading", 
         props=[("font-size", "1.05rem"),
                ("text-align", "center")]),
    dict(selector="caption", 
         props=[("font-size", "1.3rem"),
                ("color", "steelblue"),
                ("padding", "1.2rem")])
]

html = (df.style
        .set_caption("Hover to highlight")
        .apply(highlight_max, subset=monetary_fields)
        .applymap(color_lower_red, subset=['TotalPay'])
        .bar(subset=['TotalPayBenefits'], 
             color='lightsteelblue') \
        .format({field:"${:20,.0f}" for field in monetary_fields}, na_rep="-")
        .set_properties(**{'padding': '0.3rem',
                           'border-color': 'white'})
        .set_table_styles(styles)
       )
html
# Out:
# <style  type="text/css" >
#     #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002 tr:hover {
#           background-color: rgba(177, 201, 227, 0.4);
#     }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002 .col_heading {
#           font-size: 1.05rem;
#           text-align: center;
#     }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002 caption {
#           font-size: 1.3rem;
#           color: steelblue;
#           padding: 1.2rem;
#     }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col0 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col1 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col2 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col3 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col4 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col5 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col6 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col7 {
#             : ;
#             color:  green;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col8 {
#             : ;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 62.0%, transparent 62.0%);
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col9 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col10 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col11 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row0_col12 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col0 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col1 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col2 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col3 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col4 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col5 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col6 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col7 {
#             : ;
#             color:  red;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col8 {
#             : ;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 2.2%, transparent 2.2%);
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col9 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col10 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col11 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row1_col12 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col0 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col1 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col2 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col3 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col4 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col5 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col6 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col7 {
#             : ;
#             color:  green;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col8 {
#             : ;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 49.6%, transparent 49.6%);
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col9 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col10 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col11 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row2_col12 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col0 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col1 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col2 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col3 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col4 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col5 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col6 {
#             : ;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col7 {
#             : ;
#             color:  green;
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col8 {
#             : ;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightsteelblue 67.3%, transparent 67.3%);
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col9 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col10 {
#             padding:  0.3rem;
#             border-color:  white;
#         }    #T_316e4ea8_b02c_11ea_bc91_0242ac1c0002row3_col11 {
#             padding:  0.3rem;
#             border-color:  white;
